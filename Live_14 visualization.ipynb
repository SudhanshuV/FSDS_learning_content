# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.plot()    # only numerical data is plotted
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.plot(kind='area')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='area',alpha=0.4)
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='area',alpha=0.04)
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='area',alpha=0.4, stacked=False)
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x='sepal_length',y='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df.plot.scatter(x='sepal_length',y='petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width',s=900)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width',s=df['sepal_length']*10)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x='sepal_length',y='petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x='sepal_length',y='petal_length',gridsize=10)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x='sepal_length',y='petal_length',gridsize=10,cmap='viridis')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
from mpl_toolkits import mplot3d

# %%
x=np.linspace(-1,6,30)

# %%
x
# Out:
# array([-1.        , -0.75862069, -0.51724138, -0.27586207, -0.03448276,
#         0.20689655,  0.44827586,  0.68965517,  0.93103448,  1.17241379,
#         1.4137931 ,  1.65517241,  1.89655172,  2.13793103,  2.37931034,
#         2.62068966,  2.86206897,  3.10344828,  3.34482759,  3.5862069 ,
#         3.82758621,  4.06896552,  4.31034483,  4.55172414,  4.79310345,
#         5.03448276,  5.27586207,  5.51724138,  5.75862069,  6.        ])

# %%
y=np.linspace(-1,6,30)

# %%
y
# Out:
# array([-1.        , -0.75862069, -0.51724138, -0.27586207, -0.03448276,
#         0.20689655,  0.44827586,  0.68965517,  0.93103448,  1.17241379,
#         1.4137931 ,  1.65517241,  1.89655172,  2.13793103,  2.37931034,
#         2.62068966,  2.86206897,  3.10344828,  3.34482759,  3.5862069 ,
#         3.82758621,  4.06896552,  4.31034483,  4.55172414,  4.79310345,
#         5.03448276,  5.27586207,  5.51724138,  5.75862069,  6.        ])

# %%
def sin_fun(x,y):
    return np.sin(np.sqrt(x**2 + y**2))

# %%
z=sin_fun(x,y)

# %%
z
# Out:
# array([ 0.98776595,  0.87856609,  0.66797904,  0.38030669,  0.04874666,
#         0.28843877,  0.59233815,  0.82788125,  0.96788622,  0.99619638,
#         0.90954471,  0.71793089,  0.4434673 ,  0.11782723, -0.22141018,
#        -0.53509669, -0.78703263, -0.94814441, -0.99983959, -0.93615252,
#        -0.76443273, -0.50449682, -0.18634159,  0.1533176 ,  0.47528383,
#         0.74240193,  0.92384629,  0.99867807,  0.95826165,  0.80726109])

# %%
ax=plt.axes(projection='3d')
ax.plot3D(x,y,z)

# %%
z=x+y

# %%
ay=plt.axes(projection='3d')
ay.plot3D(x,y,z)
ay.set_xlabel('x')
ay.set_ylabel('y')
ay.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11].plot(kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11].plot(kind='barh',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot.hist(figsize=(20,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot(kind='hist',figsize=(20,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.sepal_length.plot(kind='hist',figsize=(20,20))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.hist(figsize=(20,10),color='y',alpha=.9)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
import cufflinks as cf

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df.iplot()
# Out:
# <div>                            <div id="dfc66f67-8fc0-4023-b293-e9f31a24a48d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x='sepal_length',y='petal_length',mode='markers',kind='scatter')
# Out:
# <div>                            <div id="a82ea92e-1386-4c4d-8daf-7a7cf730a06d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x='sepal_length',y='petal_length',size='sepal_width',kind='bubble')
# Out:
# <div>                            <div id="19985295-dcfb-4c98-9e9f-e87ee037e28f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x='sepal_length',y='petal_length',z='petal_width',size='sepal_width',kind='bubble3d')
# Out:
# <div>                            <div id="6201c017-edcc-4ab1-a01c-fb62e3c2e5b3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1=sns.load_dataset('tips')

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1.iplot(x='total_bill',y='tip',mode='markers')
# Out:
# <div>                            <div id="78102c1b-7873-4f82-bad4-198080d3567a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.plot(x='total_bill',y='tip',kind='scatter')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(x='total_bill',y='tip',data=df1)

# %%
df1.smoker.value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.relplot(x='total_bill',y='tip',data=df1,hue='smoker')

# %%
sns.relplot(x='total_bill',y='tip',data=df1,hue='time')

# %%
sns.relplot(x='total_bill',y='tip',data=df1,hue='day')

# %%
df1.day.value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
sns.relplot(x='total_bill',y='tip',data=df1,hue='time',style='smoker')

# %%
sns.relplot(x='total_bill',y='tip',data=df1,hue='time',style='sex')

# %%
sns.relplot(x='total_bill',y='tip',data=df1,hue='size',style='size')

# %%
sns.relplot(x='total_bill',y='tip',data=df1,col='time')

# %%
df1.time.value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
sns.relplot(x='total_bill',y='tip',data=df1,col='day')

# %%
df1.day.value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
sns.catplot(x='day',y='total_bill',data=df1)

# %%
sns.pairplot(df1)

# %%
sns.pairplot(df)

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="f88fcb50-8f90-47d2-9395-d4efc779a1aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2=df1.select_dtypes(include=np.number) 
# df2=df1.select_dtypes(include=['float','int'])  
# df2.select_dtypes(exclude=["number","bool_","object_"])

# %%
df2
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
df2.scatter_matrix()
# Out:
# <div>                            <div id="4c18a726-99ac-4a6d-92c3-829bd840db19" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
sns.jointplot(x=df1.total_bill,y=df1.tip)

# %%
sns.jointplot(x=df1.total_bill,y=df1.tip,kind='hex')

# %%
sns.regplot(x=df1.total_bill,y=df1.tip)
sns.set(rc={'figure.figsize':(20,10)})

# %% [markdown]
# https://github.com/santosjorge/cufflinks
#
# https://plotly.com/python/plotly-express/
#
# https://seaborn.pydata.org/index.html
#
# https://matplotlib.org/stable/index.html
#
# https://github.com/sudh9931/graph
