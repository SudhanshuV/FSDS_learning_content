# %%
import pandas as pd

# %%
data={
    'name':['sudhanshu','krish','hitesh','telusko'],
    'salary':[100,200,300,120],
    'mail_id':['sudhanshu@ai','krish@ai','hitesh@ai','telusko@ai'],
    'addr':['blr','lko','mum','mum']
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#         name  salary       mail_id addr
# 0  sudhanshu     100  sudhanshu@ai  blr
# 1      krish     200      krish@ai  lko
# 2     hitesh     300     hitesh@ai  mum
# 3    telusko     120    telusko@ai  mum

# %%
df1=pd.DataFrame(data,index=[12,3342,1354,321])

# %%
df1
# Out:
#            name  salary       mail_id addr
# 12    sudhanshu     100  sudhanshu@ai  blr
# 3342      krish     200      krish@ai  lko
# 1354     hitesh     300     hitesh@ai  mum
# 321     telusko     120    telusko@ai  mum

# %%
df1.loc[[3342,1354]]
# Out:
#         name  salary    mail_id addr
# 3342   krish     200   krish@ai  lko
# 1354  hitesh     300  hitesh@ai  mum

# %%
df1.iloc[[1,3]]
# Out:
#          name  salary     mail_id addr
# 3342    krish     200    krish@ai  lko
# 321   telusko     120  telusko@ai  mum

# %%
df1.iloc[1:3]
# Out:
#         name  salary    mail_id addr
# 3342   krish     200   krish@ai  lko
# 1354  hitesh     300  hitesh@ai  mum

# %%
data1={
    'pf_nu':[234,45,32442,3233],
    'income_tax':[234,342,43,213],
    'mobile_no':[23454325,34234243,24324324,34324433423],
    'courses':['ds','bigdata','web','blockchain']
}

# %%
df1=pd.DataFrame(data1)

# %%
df1
# Out:
#    pf_nu  income_tax    mobile_no     courses
# 0    234         234     23454325          ds
# 1     45         342     34234243     bigdata
# 2  32442          43     24324324         web
# 3   3233         213  34324433423  blockchain

# %%
c=pd.concat([df,df1])

# %%
c
# Out:
#         name  salary       mail_id addr    pf_nu  income_tax     mobile_no  \
# 0  sudhanshu   100.0  sudhanshu@ai  blr      NaN         NaN           NaN
# 1      krish   200.0      krish@ai  lko      NaN         NaN           NaN
# 2     hitesh   300.0     hitesh@ai  mum      NaN         NaN           NaN
# 3    telusko   120.0    telusko@ai  mum      NaN         NaN           NaN
# 0        NaN     NaN           NaN  NaN    234.0       234.0  2.345432e+07
# 1        NaN     NaN           NaN  NaN     45.0       342.0  3.423424e+07
# 2        NaN     NaN           NaN  NaN  32442.0        43.0  2.432432e+07
# 3        NaN     NaN           NaN  NaN   3233.0       213.0  3.432443e+10
#
#       courses
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 0          ds
# 1     bigdata
# 2         web
# 3  blockchain

# %%
c.loc[0]
# Out:
#         name  salary       mail_id addr  pf_nu  income_tax   mobile_no courses
# 0  sudhanshu   100.0  sudhanshu@ai  blr    NaN         NaN         NaN     NaN
# 0        NaN     NaN           NaN  NaN  234.0       234.0  23454325.0      ds

# %%
pd.concat([df,df1],axis=1)
# Out:
#         name  salary       mail_id addr  pf_nu  income_tax    mobile_no  \
# 0  sudhanshu     100  sudhanshu@ai  blr    234         234     23454325
# 1      krish     200      krish@ai  lko     45         342     34234243
# 2     hitesh     300     hitesh@ai  mum  32442          43     24324324
# 3    telusko     120    telusko@ai  mum   3233         213  34324433423
#
#       courses
# 0          ds
# 1     bigdata
# 2         web
# 3  blockchain

# %%
data4 = {'emp_id' : [101,102,103,104],
         'salary' : [234, 345,200,400],
         'pf' : [23,34,56,78],
         }
         
data5  = {'emp_id' : [101,102,104,105],
          'mob_no' : [3434,5656,767,878],
          'house_nu' : [345,345,345,56]
    
}

# %%
df4=pd.DataFrame(data4)

# %%
df4
# Out:
#    emp_id  salary  pf
# 0     101     234  23
# 1     102     345  34
# 2     103     200  56
# 3     104     400  78

# %%
df5=pd.DataFrame(data5)

# %%
df5
# Out:
#    emp_id  mob_no  house_nu
# 0     101    3434       345
# 1     102    5656       345
# 2     104     767       345
# 3     105     878        56

# %%
pd.merge(df4,df5)
# Out:
#    emp_id  salary  pf  mob_no  house_nu
# 0     101     234  23    3434       345
# 1     102     345  34    5656       345
# 2     104     400  78     767       345

# %%
pd.merge(df4,df5,how='left')
# Out:
#    emp_id  salary  pf  mob_no  house_nu
# 0     101     234  23  3434.0     345.0
# 1     102     345  34  5656.0     345.0
# 2     103     200  56     NaN       NaN
# 3     104     400  78   767.0     345.0

# %%
pd.merge(df4,df5,how='left',on='emp_id')
# Out:
#    emp_id  salary  pf  mob_no  house_nu
# 0     101     234  23  3434.0     345.0
# 1     102     345  34  5656.0     345.0
# 2     103     200  56     NaN       NaN
# 3     104     400  78   767.0     345.0

# %%
data6 = {'emp_id1' : [101,102,103,104],
         'salary' : [234, 345,200,400],
         'pf' : [23,34,56,78],
         }
         
data7  = {'emp_id2' : [101,102,104,105],
          'mob_no' : [3434,5656,767,878],
          'house_nu' : [345,345,345,56]
    
}

# %%
df6=pd.DataFrame(data6)

# %%
df7=pd.DataFrame(data7)

# %%
pd.merge(df6,df7,left_on='emp_id1',right_on='emp_id2',how='left')
# Out:
#    emp_id1  salary  pf  emp_id2  mob_no  house_nu
# 0      101     234  23    101.0  3434.0     345.0
# 1      102     345  34    102.0  5656.0     345.0
# 2      103     200  56      NaN     NaN       NaN
# 3      104     400  78    104.0   767.0     345.0

# %%
data8 = {'emp_id' : [101,102,103,104],
         'salary' : [234, 345,200,400],
         'pf' : [23,34,56,78]
         }
         
data9  = {'emp_id' : [101,102,104,105],
          'salary' : [234, 345,200,878],
          'house_nu' : [345,345,345,56]
    
}

# %%
df8=pd.DataFrame(data8)

# %%
df9=pd.DataFrame(data9)

# %%
pd.merge(df8,df9) # it is considering all common columns.
# Out:
#    emp_id  salary  pf  house_nu
# 0     101     234  23       345
# 1     102     345  34       345

# %%
pd.merge(df8,df9,on='emp_id')
# Out:
#    emp_id  salary_x  pf  salary_y  house_nu
# 0     101       234  23       234       345
# 1     102       345  34       345       345
# 2     104       400  78       200       345

# %%
data10 = {'emp_id1' : [101,102,103,104],
         'salary1' : [234, 345,200,400],
         'pf' : [23,34,56,78]
         }
         
data11 = {'emp_id2' : [101,102,104,105],
          'salary2' : [234, 345,200,878],
          'house_nu' : [345,345,345,56]
    
}

# %%
df10=pd.DataFrame(data10,index=['a','b','c','d'])

# %%
df11=pd.DataFrame(data11,index=['a','b','e','f'])

# %%
df10
# Out:
#    emp_id1  salary1  pf
# a      101      234  23
# b      102      345  34
# c      103      200  56
# d      104      400  78

# %%
df11
# Out:
#    emp_id2  salary2  house_nu
# a      101      234       345
# b      102      345       345
# e      104      200       345
# f      105      878        56

# %%
df10.join(df11)
# Out:
#    emp_id1  salary1  pf  emp_id2  salary2  house_nu
# a      101      234  23    101.0    234.0     345.0
# b      102      345  34    102.0    345.0     345.0
# c      103      200  56      NaN      NaN       NaN
# d      104      400  78      NaN      NaN       NaN

# %%
df_sales=pd.read_csv(r'C:\Users\Himanshu Verma\Desktop\fsds_pandas\sales_data_final.csv')

# %%
df_sales
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df_sales.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
def profit_flag(a):
    if a>=0:
        return 'positive'
    else:
        return 'negative'

# %%
l=[2,4,-3,-34,35,-8]

# %%
g=map(profit_flag,l)

# %%
for i in g:
    print(i)
# Out:
# positive
# positive
# negative
# negative
# positive
# negative

# %%
df_sales['profit_flag']= df_sales['profit'].apply(profit_flag)

# %%
df_sales
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
len(df_sales[df_sales.profit_flag=='positive'])
# Out:
# 38747

# %%
df_sales.groupby('profit_flag')['profit'].count()
# Out:
# profit_flag
# negative    12543
# positive    38747
# Name: profit, dtype: int64

# %%
df_sales['cust_len']=df_sales['customer_name'].apply(len)

# %%
df_sales
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df_sales['lambda_show']=df_sales['quantity'].apply(lambda a: a**2)

# %%
df_sales.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... sales  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...   408
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...   120
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...    66
# 3  Home Office        Stockholm     Sweden      EU    North  ...    45
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...   114
#
#   quantity discount   profit shipping_cost  order_priority  year  profit_flag  \
# ...

# %%
def qty_fg(a):
    if a<5:
        return 'low'
    elif a<10:
        return 'medium'
    else:
        return 'high'

# %%
df_sales['qty_flag']=df_sales['quantity'].apply(qty_fg)

# %%
df_sales[df_sales['qty_flag']=='high']
# Out:
#               order_id  order_date  ship_date       ship_mode  \
# 126     US-2011-163874   1/11/2011  1/12/2011     First Class
# 180    ES-2011-1043483   1/14/2011  1/19/2011  Standard Class
# 183       SF-2011-7680   1/14/2011  1/21/2011  Standard Class
# 185     MX-2011-135979   1/14/2011  1/20/2011  Standard Class
# 213     MX-2011-145765   1/17/2011  1/22/2011  Standard Class
# ...                ...         ...        ...             ...
# 51043   MX-2014-122574  12/29/2014   1/1/2015     First Class
# 51045    ID-2014-31237  12/29/2014   1/4/2015  Standard Class
# 51149  ES-2014-4675868  12/30/2014   1/2/2015     First Class
# 51161    ID-2014-52902  12/30/2014   1/1/2015     First Class
# 51258     UP-2014-3330  12/31/2014   1/2/2015     First Class
#
#              customer_name      segment             state       country  \
# 126             Philip Fox     Consumer            Mxico        Mexico
# 180         Sharelle Roach  Home Office            Vienna       Austria
# ...

# %%
import numpy as np

# %%
np.array([2,3,4,2,6,8])
# Out:
# array([2, 3, 4, 2, 6, 8])

# %%
np.array([[2,3,4],[5,4,8]])
# Out:
# array([[2, 3, 4],
#        [5, 4, 8]])

# %%
a=np.array([3,6,2,9],ndmin=3)

# %%
a
# Out:
# array([[[3, 6, 2, 9]]])

# %%
np.random.randint(1,10,(4,4))
# Out:
# array([[6, 3, 1, 9],
#        [2, 8, 9, 4],
#        [2, 2, 7, 8],
#        [9, 4, 5, 8]])

# %%
np.random.randint(1,10,(4,4,2))
# Out:
# array([[[9, 6],
#         [5, 9],
#         [3, 9],
#         [7, 2]],
#
#        [[4, 2],
#         [8, 4],
#         [2, 4],
#         [7, 2]],
#
#        [[1, 2],
#         [2, 7],
#         [6, 4],
#         [5, 5]],
#
#        [[7, 2],
#         [9, 4],
#         [1, 3],
#         [1, 8]]])
